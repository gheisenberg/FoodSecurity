# %%
from icecream import ic
import pandas as pd
# from dhs_preprocessing_functions import *
# from pandarallel import pandarallel
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import numpy as np
import os
from keras.models import Sequential
from keras.layers import Dense, Dropout
from tensorflow.keras import backend as K
import matplotlib.pyplot as plt
from tensorflow.keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
import xgboost as xgb
from keras import regularizers
from collections import defaultdict


# %matplotlib inline
# Initialization
# pandarallel.initialize()


from dhs_modelling_functions import *

# %%
# to dos:
# 1. add a function to plot the feature importance
# 2. add a function to plot the partial dependence plots
# 3. implement train, val test in modeling function
# 4. use r2 score as a loss function

# %%
input_dir = "/mnt/datadisk/data/Projects/water/inputs/"
out_dir = input_dir + 'DHS_cross_val_results/'
# min_version = 3
overwrite_pqt = True
dataset_type = 'HR'  #, 'BR', 'CR', 'HW', 'IR', 'KR', 'MR', 'PR', 'AR'] ??['AN', 'FC, 'FP', 'HW', 'PV', 'SC'] < 25 surveys
urban_rural_all_mode = 'all' # 'all', 'U', 'R'
group_by_col = 'adm2_gaul'
# out_f = f"{input_dir}5_grouped_df_V3_{dataset_type}_{group_by_col}_joined_with_ipc_{urban_rural_all_mode}.pkl"

# Scale options
scale_numerical_data = False
scale_all_data = True
leave_out_encodings = False
zero_one_scale_categorical = False
scale_labels = True

# More Options
drop_agriculture = False
use_pca = False
drop_encodings = False
load_best_model = True
use_3_layer_nn = True
add_dropout = 0.5
regularizer_type = 'l2'
regularizer_value = 0.05
add_n = 'imputed_L2_0.5'
use_imputations = True
model_n = 'nn'
fold_by = 'survey'
print_col = 'Meta; GEID_init'
drop_perc = 20
epochs = 30
use_sustainbench = False
test_mode = False

# Combine these into a dict for results.csv
options = {
    'scale_numerical_data': scale_numerical_data,
    'scale_all_data': scale_all_data,
    'leave_out_encodings': leave_out_encodings,
    'zero_one_scale_categorical': zero_one_scale_categorical,
    'scale_labels': scale_labels,
    'drop_agriculture': drop_agriculture,
    'use_pca': use_pca,
    'drop_encodings': drop_encodings,
    'load_best_model': load_best_model,
    'use_3_layer_nn': use_3_layer_nn,
    'add_dropout': add_dropout,
    'regularizer': regularizer_type,
    'regularizer_value': regularizer_value,
    'add_n': add_n,
    'use_imputations': use_imputations,
    'model_n': model_n,
    'fold_by': fold_by,
    'print_col': print_col,
    'drop_perc': drop_perc,
    'epochs': epochs,
    'use_sustainbench': use_sustainbench,
    'test_mode': test_mode,
}

#Other Options
overwrite_results = False
write_PDP_plots = False


in_f = f"{input_dir}5_grouped_df_V3_{dataset_type}_{group_by_col}_joined_with_ipc_{urban_rural_all_mode}.pkl"
in2 = f"{input_dir}imputation_results_fold_by_survey_mask_categoricals_together_True_split_categoricals_False_drop_perc_19_MICE KNN_DF_imputed.csv"

# result_picture_f =
result_csv_f = f"{out_dir}results.csv"

# %%
input_df = pd.read_pickle(in_f)

for c in input_df.columns:
    if 'year' in c or 'Year' in c:
        print(c)

# if urban_rural_all_mode == 'U':
#     drop_agriculture = True

drop_ds1, retrieve_ds = [], []
if drop_encodings:
    drop_ds1 = ['Meta one-hot encoding', 'Meta frequency encoding']
if use_sustainbench:
    retrieve_ds = ['DHS Sustainbench', 'FS']
df = final_ds_droping_cols(input_df, drop_meta=True, drop_food_help=True, drop_perc=drop_perc,
                           retain_month=False, drop_highly_correlated_cols=False, drop_region=True, 
                 drop_data_sets=drop_ds1, 
                 use_NAN_amount_and_replace_NANs_in_categorical=False, drop_agricultural_cols=drop_agriculture, 
                 drop_below_version=False, numerical_data=['mean'], retain_adm=False, retrieve_ds=retrieve_ds, 
                 retain_GEID_init=True, verbose=3)

for col in df.columns:
    print(col)
# Out:
# Meta; year
# DHS Cat; person fetching water: female child under 15 years old
# DHS Cat; person fetching water: male child under 15 years old
# Dropped numerical data: ['DHS Num; number of household members: median', 'DHS Num; number of household members: std', 'DHS Num; number of household members: skewness', 'DHS Num; number of household members: kurtosis', 'DHS Num; owns sheep: median', 'DHS Num; owns sheep: std', 'DHS Num; owns sheep: skewness', 'DHS Num; owns sheep: kurtosis', 'DHS Num; number of eligible children for height and weight: median', 'DHS Num; number of eligible children for height and weight: std', 'DHS Num; number of eligible children for height and weight: skewness', 'DHS Num; number of eligible children for height and weight: kurtosis', 'DHS Num; total adults measured: median', 'DHS Num; total adults measured: std', 'DHS Num; total adults measured: skewness', 'DHS Num; total adults measured: kurtosis', 'DHS Num; number of mosquito bed nets: median', 'DHS Num; number of mosquito bed nets: std', 'DHS Num; number of mosquito bed nets: skewness', 'DHS Num; number of mosquito bed nets: kurtosis', 'DHS Num; number of eligible children for height & weight: median', 'DHS Num; number of eligible children for height & weight: std', 'DHS Num; number of eligible children for height & weight: skewness', 'DHS Num; number of eligible children for height & weight: kurtosis', 'DHS Num; cluster altitude in meters: median', 'DHS Num; cluster altitude in meters: std', 'DHS Num; cluster altitude in meters: skewness', 'DHS Num; cluster altitude in meters: kurtosis', 'DHS Num; number of eligible women in household: median', 'DHS Num; number of eligible women in household: std', 'DHS Num; number of eligible women in household: skewness', 'DHS Num; number of eligible women in household: kurtosis', 'DHS Num; number of eligible men in hh: median', 'DHS Num; number of eligible men in hh: std', 'DHS Num; number of eligible men in hh: skewness', 'DHS Num; number of eligible men in hh: kurtosis', 'DHS Num; number of children 5 and under (de jure): median', 'DHS Num; number of children 5 and under (de jure): std', 'DHS Num; number of children 5 and under (de jure): skewness', 'DHS Num; number of children 5 and under (de jure): kurtosis', 'DHS Num; number of households sharing toilet: median', 'DHS Num; number of households sharing toilet: std', 'DHS Num; number of households sharing toilet: skewness', 'DHS Num; number of households sharing toilet: kurtosis', 'DHS Num; hectares of agricultural land (1 decimal): median', 'DHS Num; hectares of agricultural land (1 decimal): std', 'DHS Num; hectares of agricultural land (1 decimal): skewness', 'DHS Num; hectares of agricultural land (1 decimal): kurtosis', 'DHS Num; number of rooms used for sleeping: median', 'DHS Num; number of rooms used for sleeping: std', 'DHS Num; number of rooms used for sleeping: skewness', 'DHS Num; number of rooms used for sleeping: kurtosis', 'DHS Num; owns goats: median', 'DHS Num; owns goats: std', 'DHS Num; owns goats: skewness', 'DHS Num; owns goats: kurtosis', 'DHS Num; owns horses/ donkeys/ mules: median', 'DHS Num; owns horses/ donkeys/ mules: std', 'DHS Num; owns horses/ donkeys/ mules: skewness', 'DHS Num; owns horses/ donkeys/ mules: kurtosis', 'DHS Num; time to get to water source (minutes): median', 'DHS Num; time to get to water source (minutes): std', 'DHS Num; time to get to water source (minutes): skewness', 'DHS Num; time to get to water source (minutes): kurtosis', 'DHS Num; owns cows/ bulls: median', 'DHS Num; owns cows/ bulls: std', 'DHS Num; owns cows/ bulls: skewness', 'DHS Num; owns cows/ bulls: kurtosis', 'DHS Num; owns chickens/poultry: median', 'DHS Num; owns chickens/poultry: std', 'DHS Num; owns chickens/poultry: skewness', 'DHS Num; owns chickens/poultry: kurtosis']
# Dropped one of double cat similar length DHS Cat; type of place of residence: urban
# Dropped one of double cat similar length DHS Cat; has electricity: no
# Dropped one of double cat similar length DHS Cat; has radio: no
# Dropped one of double cat similar length DHS Cat; has bicycle: no
# Dropped one of double cat similar length DHS Cat; has car/truck: no
# Dropped one of double cat similar length DHS Cat; has refrigerator: no
# Dropped one of double cat similar length DHS Cat; has telephone (land-line): no
# Dropped one of double cat similar length DHS Cat; has bank account: no
# Dropped one of double cat similar length DHS Cat; anything done to water to make safe to drink: no
# Dropped one of double cat similar length DHS Cat; water usually treated by: boil: no
# Dropped one of double cat similar length DHS Cat; water usually treated by: add bleach/chlorine: no
# Dropped one of double cat similar length DHS Cat; household selected for domestic violence module: household selected: dv women
# Dropped single cat DHS Cat; place where household members wash their hands: not observed: not in dwelling
# Dropped one of double cat similar length DHS Cat; has dwelling been sprayed against mosquitoes in last 12 months: no
# Dropped one of double cat similar length DHS Cat; dwelling sprayed by: government worker/program: no
# Dropped one of double cat similar length DHS Cat; dwelling sprayed by: private company: no
# Dropped one of double cat similar length DHS Cat; dwelling sprayed by: ngo: no
# Dropped one of double cat similar length DHS Cat; dwelling sprayed by: other: no
# Dropped one of double cat similar length DHS Cat; water usually treated by: strain through a cloth: no
# Dropped one of double cat similar length DHS Cat; water usually treated by: let it stand and settle: no
# Dropped one of double cat similar length DHS Cat; has watch: no
# Dropped one of double cat similar length DHS Cat; has boat with a motor: no
# Dropped one of double cat similar length DHS Cat; has animal-drawn cart: no
# Dropped one of double cat similar length DHS Cat; has a computer: no
# Dropped one of double cat similar length DHS Cat; water usually treated by: other: no
# Dropped one of double cat similar length DHS Cat; water usually treated by: solar disinfection: no
# Dropped one of double cat similar length DHS Cat; table: no
# Dropped one of double cat similar length DHS Cat; has mobile telephone: no
# Dropped one of double cat similar length DHS Cat; owns land usable for agriculture: no
# Dropped one of double cat similar length DHS Cat; has television: no
# Dropped one of double cat similar length DHS Cat; has motorcycle/scooter: no
# Dropped one of double cat similar length DHS Cat; water usually treated by: use water filter: no
# Dropped one of double cat similar length DHS Cat; owns livestock, herds or farm animals: no
# Dropped one of double cat similar length DHS Cat; number of households sharing toilet: applicable: not applicable
# Dropped one of double cat similar length DHS Cat; URBAN_RURA: U
# Dropped 1447, retaining columns: 183
# Dropped following subsets of numerical data: {'median', 'skewness', 'std', 'kurtosis'}
# Retained following subsets of food security data:
#    mean
#    long time spans.
# Dropped 6-7y True
#     20-25y True
# Dropped: food help True
#     IPC w/o food help False
# Dropped meta data True and region True
# Dropped columns with less than 20% of available values
# Dropped meta: Meta; adm2_gaul: 100.0%
# Dropped meta: Meta; adm1_gaul: 100.0%
# Dropped meta: Meta; month: 100.0%
# Dropped meta: Meta; date: 100.0%
# Dropped meta: Meta; amount of households: 100.0%
# Dropped meta: Meta; DHS Num; number of household members: percentage of valid answers: 100.0%
# Dropped meta: Meta; DHS Num; owns sheep: percentage of valid answers: 100.0%
# Dropped meta: Meta; DHS Num; number of eligible children for height and weight: percentage of valid answers: 100.0%
# Dropped meta: Meta; DHS Num; total adults measured: percentage of valid answers: 100.0%
# Dropped meta: Meta; DHS Num; number of mosquito bed nets: percentage of valid answers: 100.0%
# Dropped meta: Meta; DHS Num; owns rabbits: percentage of valid answers: 100.0%
# Dropped meta: Meta; DHS Num; number of eligible children for height & weight: percentage of valid answers: 100.0%
# Dropped meta: Meta; DHS Num; cluster altitude in meters: percentage of valid answers: 100.0%
# Dropped meta: Meta; DHS Num; number of eligible women in household: percentage of valid answers: 100.0%
# Dropped meta: Meta; DHS Num; number of eligible men in hh: percentage of valid answers: 100.0%
# Dropped meta: Meta; DHS Num; number of children 5 and under (de jure): percentage of valid answers: 100.0%
# Dropped meta: Meta; DHS Num; number of households sharing toilet: percentage of valid answers: 100.0%
# Dropped meta: Meta; DHS Num; hectares of agricultural land (1 decimal): percentage of valid answers: 100.0%
# Dropped meta: Meta; DHS Num; number of rooms used for sleeping: percentage of valid answers: 100.0%
# Dropped meta: Meta; DHS Num; owns goats: percentage of valid answers: 100.0%
# Dropped meta: Meta; DHS Num; owns horses/ donkeys/ mules: percentage of valid answers: 100.0%
# Dropped meta: Meta; DHS Num; time to get to water source (minutes): percentage of valid answers: 100.0%
# Dropped meta: Meta; DHS Num; owns cows/ bulls: percentage of valid answers: 100.0%
# Dropped meta: Meta; DHS Num; owns chickens/poultry: percentage of valid answers: 100.0%
# Dropped meta: DHS Num; owns rabbits: mean: 11.9%
# Dropped meta: DHS Cat; water not available for at least a day last two weeks: no, not interrupted for a full day: 13.8%
# Dropped meta: DHS Cat; type of cookstove: electric stove: 5.9%
# Dropped meta: DHS Cat; person fetching water: adult man: 16.9%
# Dropped meta: DHS Cat; has generator: no: 13.9%
# Dropped meta: DHS Cat; has fan: no: 19.8%
# Dropped meta: DHS Cat; dvd player: no: 11.8%
# Dropped meta: DHS Cat; sewing machine: no: 18.4%
# Dropped meta: DHS Cat; has bed: no: 15.5%
# Dropped meta: DHS Cat; chair: no: 13.1%
# Dropped meta: DHS Education; Female Education PCA: 9.4%
# Dropped meta: DHS Education; Female Education PCA (min-max-scaled): 9.4%
# Dropped meta: DHS Education; EDI: 9.0%
# Dropped meta: DHS Education; EDI (min-max-scaled): 9.0%
# Dropped meta: DHS Education; EDI (UNESCO): 6.5%
# Dropped meta: DHS Education; EDI (UNESCO) (min-max-scaled): 6.5%
# Dropped meta: DHS Education; principal component 1_child: 9.4%
# Dropped meta: DHS Education; principal component 1 (min-max-scaled)_child: 9.4%
# Dropped meta: DHS Education; principal component 1_aduld: 9.4%
# Dropped meta: DHS Education; principal component 1 (min-max-scaled)_aduld: 9.4%
# Dropped meta: DHS Education; principal component 1_youth: 9.4%
# Dropped meta: DHS Education; principal component 1 (min-max-scaled)_youth: 9.4%
# Remaining columns:
# Remaining: Meta; GEID_init: 100.0%
# Remaining: Meta; adm0_gaul: 100.0%
# Remaining: Meta; year: 100.0%
# Remaining: Meta one-hot encoding; adm0_gaul: Angola: 100.0%
# Remaining: Meta one-hot encoding; adm0_gaul: Benin: 100.0%
# Remaining: Meta one-hot encoding; adm0_gaul: Burkina Faso: 100.0%
# Remaining: Meta one-hot encoding; adm0_gaul: Burundi: 100.0%
# Remaining: Meta one-hot encoding; adm0_gaul: Cameroon: 100.0%
# Remaining: Meta one-hot encoding; adm0_gaul: Central African Republic: 100.0%
# Remaining: Meta one-hot encoding; adm0_gaul: Chad: 100.0%
# Remaining: Meta one-hot encoding; adm0_gaul: Comoros: 100.0%
# Remaining: Meta one-hot encoding; adm0_gaul: Côte d'Ivoire: 100.0%
# Remaining: Meta one-hot encoding; adm0_gaul: Democratic Republic of the Congo: 100.0%
# Remaining: Meta one-hot encoding; adm0_gaul: Egypt: 100.0%
# Remaining: Meta one-hot encoding; adm0_gaul: Ethiopia: 100.0%
# Remaining: Meta one-hot encoding; adm0_gaul: Gabon: 100.0%
# Remaining: Meta one-hot encoding; adm0_gaul: Gambia: 100.0%
# Remaining: Meta one-hot encoding; adm0_gaul: Ghana: 100.0%
# Remaining: Meta one-hot encoding; adm0_gaul: Guinea: 100.0%
# Remaining: Meta one-hot encoding; adm0_gaul: Kenya: 100.0%
# Remaining: Meta one-hot encoding; adm0_gaul: Lesotho: 100.0%
# Remaining: Meta one-hot encoding; adm0_gaul: Liberia: 100.0%
# Remaining: Meta one-hot encoding; adm0_gaul: Madagascar: 100.0%
# Remaining: Meta one-hot encoding; adm0_gaul: Malawi: 100.0%
# Remaining: Meta one-hot encoding; adm0_gaul: Mali: 100.0%
# Remaining: Meta one-hot encoding; adm0_gaul: Morocco: 100.0%
# Remaining: Meta one-hot encoding; adm0_gaul: Mozambique: 100.0%
# Remaining: Meta one-hot encoding; adm0_gaul: Namibia: 100.0%
# Remaining: Meta one-hot encoding; adm0_gaul: Niger: 100.0%
# Remaining: Meta one-hot encoding; adm0_gaul: Nigeria: 100.0%
# Remaining: Meta one-hot encoding; adm0_gaul: Rwanda: 100.0%
# Remaining: Meta one-hot encoding; adm0_gaul: Senegal: 100.0%
# Remaining: Meta one-hot encoding; adm0_gaul: Sierra Leone: 100.0%
# Remaining: Meta one-hot encoding; adm0_gaul: South Africa: 100.0%
# Remaining: Meta one-hot encoding; adm0_gaul: Swaziland: 100.0%
# Remaining: Meta one-hot encoding; adm0_gaul: Togo: 100.0%
# Remaining: Meta one-hot encoding; adm0_gaul: Uganda: 100.0%
# Remaining: Meta one-hot encoding; adm0_gaul: United Republic of Tanzania: 100.0%
# Remaining: Meta one-hot encoding; adm0_gaul: Zambia: 100.0%
# Remaining: Meta one-hot encoding; adm0_gaul: Zimbabwe: 100.0%
# Remaining: Meta frequency encoding; adm1_gaul: 100.0%
# Remaining: Meta frequency encoding; adm2_gaul: 100.0%
# Remaining: DHS Num; number of household members: mean: 100.0%
# Remaining: DHS Num; owns sheep: mean: 69.1%
# Remaining: DHS Num; number of eligible children for height and weight: mean: 55.4%
# Remaining: DHS Num; total adults measured: mean: 64.9%
# Remaining: DHS Num; number of mosquito bed nets: mean: 52.9%
# Remaining: DHS Num; number of eligible children for height & weight: mean: 31.2%
# Remaining: DHS Num; cluster altitude in meters: mean: 62.6%
# Remaining: DHS Num; number of eligible women in household: mean: 99.7%
# Remaining: DHS Num; number of eligible men in hh: mean: 33.1%
# Remaining: DHS Num; number of children 5 and under (de jure): mean: 95.9%
# Remaining: DHS Num; number of households sharing toilet: mean: 96.9%
# Remaining: DHS Num; hectares of agricultural land (1 decimal): mean: 68.2%
# Remaining: DHS Num; number of rooms used for sleeping: mean: 77.9%
# Remaining: DHS Num; owns goats: mean: 70.0%
# Remaining: DHS Num; owns horses/ donkeys/ mules: mean: 70.0%
# Remaining: DHS Num; time to get to water source (minutes): mean: 99.3%
# Remaining: DHS Num; owns cows/ bulls: mean: 71.6%
# Remaining: DHS Num; owns chickens/poultry: mean: 69.0%
# Remaining: DHS Cat; type of place of residence: rural: 100.0%
# Remaining: DHS Cat; source of drinking water: other: 99.7%
# Remaining: DHS Cat; source of drinking water: piped into dwelling: 99.7%
# Remaining: DHS Cat; source of drinking water: piped to neighbor: 99.7%
# Remaining: DHS Cat; source of drinking water: piped to yard/plot: 99.7%
# Remaining: DHS Cat; source of drinking water: protected spring: 99.7%
# Remaining: DHS Cat; source of drinking water: protected well: 99.7%
# Remaining: DHS Cat; source of drinking water: public tap/standpipe: 99.7%
# Remaining: DHS Cat; source of drinking water: rainwater: 99.7%
# Remaining: DHS Cat; source of drinking water: river/dam/lake/ponds/stream/canal/irrigation channel: 99.7%
# Remaining: DHS Cat; source of drinking water: sachet water: 99.7%
# Remaining: DHS Cat; source of drinking water: tube well or borehole: 99.7%
# Remaining: DHS Cat; source of drinking water: unprotected spring: 99.7%
# Remaining: DHS Cat; source of drinking water: unprotected well: 99.7%
# Remaining: DHS Cat; source of drinking water: water seller: 99.7%
# Remaining: DHS Cat; source of drinking water: well in residence: 99.7%
# Remaining: DHS Cat; has electricity: yes: 99.7%
# Remaining: DHS Cat; has radio: yes: 98.0%
# Remaining: DHS Cat; has bicycle: yes: 99.7%
# Remaining: DHS Cat; has car/truck: yes: 91.7%
# Remaining: DHS Cat; type of toilet facility: flush to piped sewer system: 99.7%
# Remaining: DHS Cat; type of toilet facility: flush to pit latrine: 99.7%
# Remaining: DHS Cat; type of toilet facility: flush to septic tank: 99.7%
# Remaining: DHS Cat; type of toilet facility: modern flush toilet: 99.7%
# Remaining: DHS Cat; type of toilet facility: no facility/bush/field: 99.7%
# Remaining: DHS Cat; type of toilet facility: other flush: 99.7%
# Remaining: DHS Cat; type of toilet facility: pit latrine with slab: 99.7%
# Remaining: DHS Cat; type of toilet facility: pit latrine without slab/open pit: 99.7%
# Remaining: DHS Cat; type of toilet facility: traditional bucket flush: 99.7%
# Remaining: DHS Cat; type of toilet facility: traditional pit toilet: 99.7%
# Remaining: DHS Cat; type of toilet facility: ventilated improved pit latrine (vip): 99.7%
# Remaining: DHS Cat; has refrigerator: yes: 98.1%
# Remaining: DHS Cat; translator used: no: 49.8%
# Remaining: DHS Cat; translator used: not at all: 49.8%
# Remaining: DHS Cat; translator used: yes: 49.8%
# Remaining: DHS Cat; has telephone (land-line): yes: 55.7%
# Remaining: DHS Cat; has bank account: yes: 55.6%
# Remaining: DHS Cat; share toilet with other households: no: 97.0%
# Remaining: DHS Cat; share toilet with other households: not applicable: 97.0%
# Remaining: DHS Cat; share toilet with other households: yes: 97.0%
# Remaining: DHS Cat; location of source for water: elsewhere: 99.7%
# Remaining: DHS Cat; location of source for water: in own dwelling: 99.7%
# Remaining: DHS Cat; location of source for water: in own yard/plot: 99.7%
# Remaining: DHS Cat; anything done to water to make safe to drink: yes: 50.2%
# Remaining: DHS Cat; water usually treated by: boil: yes: 50.2%
# Remaining: DHS Cat; water usually treated by: add bleach/chlorine: yes: 50.2%
# Remaining: DHS Cat; household selected for domestic violence module: household not selected: 31.2%
# Remaining: DHS Cat; household selected for domestic violence module: household selected: 31.2%
# Remaining: DHS Cat; household selected for domestic violence module: household selected: dv men: 31.2%
# Remaining: DHS Cat; household selected for domestic violence module: man selected: 31.2%
# Remaining: DHS Cat; household selected for domestic violence module: woman selected: 31.2%
# Remaining: DHS Cat; place where household members wash their hands: not observed other: 34.8%
# Remaining: DHS Cat; place where household members wash their hands: observed: 34.8%
# Remaining: DHS Cat; place where household members wash their hands: observed, fixed place: 34.8%
# Remaining: DHS Cat; place where household members wash their hands: observed, mobile place: 34.8%
# Remaining: DHS Cat; presence of water at hand washing place: not applicable: 34.8%
# Remaining: DHS Cat; presence of water at hand washing place: water is available: 34.8%
# Remaining: DHS Cat; presence of water at hand washing place: water not available: 34.8%
# Remaining: DHS Cat; items present: soap or detergent: no: 34.8%
# Remaining: DHS Cat; items present: soap or detergent: not applicable: 34.8%
# Remaining: DHS Cat; items present: soap or detergent: yes: 34.8%
# Remaining: DHS Cat; items present: ash, mud, sand: no: 34.8%
# Remaining: DHS Cat; items present: ash, mud, sand: not applicable: 34.8%
# Remaining: DHS Cat; items present: ash, mud, sand: yes: 34.8%
# Remaining: DHS Cat; items present: none: no: 34.8%
# Remaining: DHS Cat; items present: none: not applicable: 34.8%
# Remaining: DHS Cat; items present: none: yes, no cleansing agent observed: 34.8%
# Remaining: DHS Cat; location of toilet facility: elsewhere: 81.7%
# Remaining: DHS Cat; location of toilet facility: in own dwelling: 81.7%
# Remaining: DHS Cat; location of toilet facility: in own yard/plot: 81.7%
# Remaining: DHS Cat; has dwelling been sprayed against mosquitoes in last 12 months: yes: 32.5%
# Remaining: DHS Cat; dwelling sprayed by: government worker/program: yes: 33.5%
# Remaining: DHS Cat; dwelling sprayed by: private company: yes: 33.5%
# Remaining: DHS Cat; dwelling sprayed by: ngo: yes: 31.2%
# Remaining: DHS Cat; dwelling sprayed by: other: yes: 33.5%
# Remaining: DHS Cat; household has separate room used as kitchen: no: 45.6%
# Remaining: DHS Cat; household has separate room used as kitchen: not applicable: 45.6%
# Remaining: DHS Cat; household has separate room used as kitchen: yes: 45.6%
# Remaining: DHS Cat; result of salt test for iodine: iodine present: 31.1%
# Remaining: DHS Cat; result of salt test for iodine: no iodine: 31.1%
# Remaining: DHS Cat; result of salt test for iodine: salt not tested: 31.1%
# Remaining: DHS Cat; water usually treated by: strain through a cloth: yes: 49.7%
# Remaining: DHS Cat; water usually treated by: let it stand and settle: yes: 51.9%
# Remaining: DHS Cat; has watch: yes: 62.3%
# Remaining: DHS Cat; has boat with a motor: yes: 60.6%
# Remaining: DHS Cat; has animal-drawn cart: yes: 57.3%
# Remaining: DHS Cat; place of residence: capital, large city: 38.3%
# Remaining: DHS Cat; place of residence: countryside: 38.3%
# Remaining: DHS Cat; place of residence: small city: 38.3%
# Remaining: DHS Cat; has a computer: yes: 43.2%
# Remaining: DHS Cat; water usually treated by: other: yes: 52.2%
# Remaining: DHS Cat; water usually treated by: solar disinfection: yes: 51.2%
# Remaining: DHS Cat; type of cooking fuel: animal dung: 87.8%
# Remaining: DHS Cat; type of cooking fuel: charcoal: 87.8%
# Remaining: DHS Cat; type of cooking fuel: electricity: 87.8%
# Remaining: DHS Cat; type of cooking fuel: firewood, straw: 87.8%
# Remaining: DHS Cat; type of cooking fuel: kerosene: 87.8%
# Remaining: DHS Cat; type of cooking fuel: lpg: 87.8%
# Remaining: DHS Cat; type of cooking fuel: no food cooked in house: 87.8%
# Remaining: DHS Cat; type of cooking fuel: other: 87.8%
# Remaining: DHS Cat; type of cooking fuel: wood: 87.8%
# Remaining: DHS Cat; food cooked in the house/ separate building/ outdoors: in a separate building: 45.7%
# Remaining: DHS Cat; food cooked in the house/ separate building/ outdoors: in the house: 45.7%
# Remaining: DHS Cat; food cooked in the house/ separate building/ outdoors: outdoors: 45.7%
# Remaining: DHS Cat; table: yes: 30.3%
# Remaining: DHS Cat; has mobile telephone: yes: 78.1%
# Remaining: DHS Cat; owns land usable for agriculture: yes: 68.6%
# Remaining: DHS Cat; has television: yes: 96.9%
# Remaining: DHS Cat; has motorcycle/scooter: yes: 99.7%
# Remaining: DHS Cat; water usually treated by: use water filter: yes: 52.2%
# Remaining: DHS Cat; owns livestock, herds or farm animals: yes: 69.1%
# Remaining: DHS Cat; number of households sharing toilet: applicable: applicable: 100.0%
# Remaining: DHS Cat; URBAN_RURA: R: 100.0%
# Remaining: FS; IPC: 0-2y: mean: 38.7%
# Remaining: FS; IPC: 2-6y: mean: 41.2%
# Remaining: FS; IPC: 6-12y: mean: 36.6%
# Remaining: FS; IPC: 12-20y: mean: 15.2%
# Remaining: DHS Sustainbench; asset_index: 56.3%
# Remaining: DHS Sustainbench; water_index: 56.3%
# Remaining: DHS Sustainbench; sanitation_index: 56.3%
# Remaining: DHS Sustainbench; under5_mort: 67.8%
# Remaining: DHS Sustainbench; women_edu: 74.7%
# Remaining: DHS Sustainbench; women_bmi: 46.5%
# Meta; GEID_init
# Meta; adm0_gaul
# Meta; year
# Meta one-hot encoding; adm0_gaul: Angola
# Meta one-hot encoding; adm0_gaul: Benin
# Meta one-hot encoding; adm0_gaul: Burkina Faso
# Meta one-hot encoding; adm0_gaul: Burundi
# Meta one-hot encoding; adm0_gaul: Cameroon
# Meta one-hot encoding; adm0_gaul: Central African Republic
# Meta one-hot encoding; adm0_gaul: Chad
# Meta one-hot encoding; adm0_gaul: Comoros
# Meta one-hot encoding; adm0_gaul: Côte d'Ivoire
# Meta one-hot encoding; adm0_gaul: Democratic Republic of the Congo
# Meta one-hot encoding; adm0_gaul: Egypt
# Meta one-hot encoding; adm0_gaul: Ethiopia
# Meta one-hot encoding; adm0_gaul: Gabon
# Meta one-hot encoding; adm0_gaul: Gambia
# Meta one-hot encoding; adm0_gaul: Ghana
# Meta one-hot encoding; adm0_gaul: Guinea
# Meta one-hot encoding; adm0_gaul: Kenya
# Meta one-hot encoding; adm0_gaul: Lesotho
# Meta one-hot encoding; adm0_gaul: Liberia
# Meta one-hot encoding; adm0_gaul: Madagascar
# Meta one-hot encoding; adm0_gaul: Malawi
# Meta one-hot encoding; adm0_gaul: Mali
# Meta one-hot encoding; adm0_gaul: Morocco
# Meta one-hot encoding; adm0_gaul: Mozambique
# Meta one-hot encoding; adm0_gaul: Namibia
# Meta one-hot encoding; adm0_gaul: Niger
# Meta one-hot encoding; adm0_gaul: Nigeria
# Meta one-hot encoding; adm0_gaul: Rwanda
# Meta one-hot encoding; adm0_gaul: Senegal
# Meta one-hot encoding; adm0_gaul: Sierra Leone
# Meta one-hot encoding; adm0_gaul: South Africa
# Meta one-hot encoding; adm0_gaul: Swaziland
# Meta one-hot encoding; adm0_gaul: Togo
# Meta one-hot encoding; adm0_gaul: Uganda
# Meta one-hot encoding; adm0_gaul: United Republic of Tanzania
# Meta one-hot encoding; adm0_gaul: Zambia
# Meta one-hot encoding; adm0_gaul: Zimbabwe
# Meta frequency encoding; adm1_gaul
# Meta frequency encoding; adm2_gaul
# DHS Num; number of household members: mean
# DHS Num; owns sheep: mean
# DHS Num; number of eligible children for height and weight: mean
# DHS Num; total adults measured: mean
# DHS Num; number of mosquito bed nets: mean
# DHS Num; number of eligible children for height & weight: mean
# DHS Num; cluster altitude in meters: mean
# DHS Num; number of eligible women in household: mean
# DHS Num; number of eligible men in hh: mean
# DHS Num; number of children 5 and under (de jure): mean
# DHS Num; number of households sharing toilet: mean
# DHS Num; hectares of agricultural land (1 decimal): mean
# DHS Num; number of rooms used for sleeping: mean
# DHS Num; owns goats: mean
# DHS Num; owns horses/ donkeys/ mules: mean
# DHS Num; time to get to water source (minutes): mean
# DHS Num; owns cows/ bulls: mean
# DHS Num; owns chickens/poultry: mean
# DHS Cat; type of place of residence: rural
# DHS Cat; source of drinking water: other
# DHS Cat; source of drinking water: piped into dwelling
# DHS Cat; source of drinking water: piped to neighbor
# DHS Cat; source of drinking water: piped to yard/plot
# DHS Cat; source of drinking water: protected spring
# DHS Cat; source of drinking water: protected well
# DHS Cat; source of drinking water: public tap/standpipe
# DHS Cat; source of drinking water: rainwater
# DHS Cat; source of drinking water: river/dam/lake/ponds/stream/canal/irrigation channel
# DHS Cat; source of drinking water: sachet water
# DHS Cat; source of drinking water: tube well or borehole
# DHS Cat; source of drinking water: unprotected spring
# DHS Cat; source of drinking water: unprotected well
# DHS Cat; source of drinking water: water seller
# DHS Cat; source of drinking water: well in residence
# DHS Cat; has electricity: yes
# DHS Cat; has radio: yes
# DHS Cat; has bicycle: yes
# DHS Cat; has car/truck: yes
# DHS Cat; type of toilet facility: flush to piped sewer system
# DHS Cat; type of toilet facility: flush to pit latrine
# DHS Cat; type of toilet facility: flush to septic tank
# DHS Cat; type of toilet facility: modern flush toilet
# DHS Cat; type of toilet facility: no facility/bush/field
# DHS Cat; type of toilet facility: other flush
# DHS Cat; type of toilet facility: pit latrine with slab
# DHS Cat; type of toilet facility: pit latrine without slab/open pit
# DHS Cat; type of toilet facility: traditional bucket flush
# DHS Cat; type of toilet facility: traditional pit toilet
# DHS Cat; type of toilet facility: ventilated improved pit latrine (vip)
# DHS Cat; has refrigerator: yes
# DHS Cat; translator used: no
# DHS Cat; translator used: not at all
# DHS Cat; translator used: yes
# DHS Cat; has telephone (land-line): yes
# DHS Cat; has bank account: yes
# DHS Cat; share toilet with other households: no
# DHS Cat; share toilet with other households: not applicable
# DHS Cat; share toilet with other households: yes
# DHS Cat; location of source for water: elsewhere
# DHS Cat; location of source for water: in own dwelling
# DHS Cat; location of source for water: in own yard/plot
# DHS Cat; anything done to water to make safe to drink: yes
# DHS Cat; water usually treated by: boil: yes
# DHS Cat; water usually treated by: add bleach/chlorine: yes
# DHS Cat; household selected for domestic violence module: household not selected
# DHS Cat; household selected for domestic violence module: household selected
# DHS Cat; household selected for domestic violence module: household selected: dv men
# DHS Cat; household selected for domestic violence module: man selected
# DHS Cat; household selected for domestic violence module: woman selected
# DHS Cat; place where household members wash their hands: not observed other
# DHS Cat; place where household members wash their hands: observed
# DHS Cat; place where household members wash their hands: observed, fixed place
# DHS Cat; place where household members wash their hands: observed, mobile place
# DHS Cat; presence of water at hand washing place: not applicable
# DHS Cat; presence of water at hand washing place: water is available
# DHS Cat; presence of water at hand washing place: water not available
# DHS Cat; items present: soap or detergent: no
# DHS Cat; items present: soap or detergent: not applicable
# DHS Cat; items present: soap or detergent: yes
# DHS Cat; items present: ash, mud, sand: no
# DHS Cat; items present: ash, mud, sand: not applicable
# DHS Cat; items present: ash, mud, sand: yes
# DHS Cat; items present: none: no
# DHS Cat; items present: none: not applicable
# DHS Cat; items present: none: yes, no cleansing agent observed
# DHS Cat; location of toilet facility: elsewhere
# DHS Cat; location of toilet facility: in own dwelling
# DHS Cat; location of toilet facility: in own yard/plot
# DHS Cat; has dwelling been sprayed against mosquitoes in last 12 months: yes
# DHS Cat; dwelling sprayed by: government worker/program: yes
# DHS Cat; dwelling sprayed by: private company: yes
# DHS Cat; dwelling sprayed by: ngo: yes
# DHS Cat; dwelling sprayed by: other: yes
# DHS Cat; household has separate room used as kitchen: no
# DHS Cat; household has separate room used as kitchen: not applicable
# DHS Cat; household has separate room used as kitchen: yes
# DHS Cat; result of salt test for iodine: iodine present
# DHS Cat; result of salt test for iodine: no iodine
# DHS Cat; result of salt test for iodine: salt not tested
# DHS Cat; water usually treated by: strain through a cloth: yes
# DHS Cat; water usually treated by: let it stand and settle: yes
# DHS Cat; has watch: yes
# DHS Cat; has boat with a motor: yes
# DHS Cat; has animal-drawn cart: yes
# DHS Cat; place of residence: capital, large city
# DHS Cat; place of residence: countryside
# DHS Cat; place of residence: small city
# DHS Cat; has a computer: yes
# DHS Cat; water usually treated by: other: yes
# DHS Cat; water usually treated by: solar disinfection: yes
# DHS Cat; type of cooking fuel: animal dung
# DHS Cat; type of cooking fuel: charcoal
# DHS Cat; type of cooking fuel: electricity
# DHS Cat; type of cooking fuel: firewood, straw
# DHS Cat; type of cooking fuel: kerosene
# DHS Cat; type of cooking fuel: lpg
# DHS Cat; type of cooking fuel: no food cooked in house
# DHS Cat; type of cooking fuel: other
# DHS Cat; type of cooking fuel: wood
# DHS Cat; food cooked in the house/ separate building/ outdoors: in a separate building
# DHS Cat; food cooked in the house/ separate building/ outdoors: in the house
# DHS Cat; food cooked in the house/ separate building/ outdoors: outdoors
# DHS Cat; table: yes
# DHS Cat; has mobile telephone: yes
# DHS Cat; owns land usable for agriculture: yes
# DHS Cat; has television: yes
# DHS Cat; has motorcycle/scooter: yes
# DHS Cat; water usually treated by: use water filter: yes
# DHS Cat; owns livestock, herds or farm animals: yes
# DHS Cat; number of households sharing toilet: applicable: applicable
# DHS Cat; URBAN_RURA: R
# FS; IPC: 0-2y: mean
# FS; IPC: 2-6y: mean
# FS; IPC: 6-12y: mean
# FS; IPC: 12-20y: mean
# DHS Sustainbench; asset_index
# DHS Sustainbench; water_index
# DHS Sustainbench; sanitation_index
# DHS Sustainbench; under5_mort
# DHS Sustainbench; women_edu
# DHS Sustainbench; women_bmi

# %%
missing_mask = False
if use_imputations:
    df_imputed = pd.read_csv(in2).drop(columns=['Unnamed: 0'])
    use_cols = [c for c in df_imputed.columns if c in df.columns]
    # Create a mask of missing values
    missing_mask = df[use_cols].isna()
    df = pd.concat([df.drop(columns=use_cols), df_imputed[use_cols]], axis=1)

# %%
# Define RMSE
def root_mean_squared_error(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
label_df = df[[c for c in df.columns if 'FS; IPC' in c]]
input_df2 = df.drop(columns=[c for c in df.columns if 'FS; IPC' in c])
num_cols = [c for c in input_df2.columns if 'DHS Num;' in c or c == 'Meta; Year' or c == 'Meta; Month']

# %%
label_cols = [c for c in df.columns if 'FS; IPC' in c]
scaler_l = []
history_l = []
y_test_l = []
y_pred_l = []
model_l = []
amount_inputs = []
amount_cols = []

if os.path.exists(result_csv_f) and not overwrite_results:
    final_result_df = pd.read_csv(result_csv_f)
else:
    final_result_df = pd.DataFrame()

regularizer = None
if regularizer_type == 'l2':
    regularizer = regularizers.l2(regularizer_value)
elif regularizer_type == 'l1':
    regularizer = regularizers.l1(regularizer_value)

all_results_dfs = []
results_d = defaultdict(list)
results_f_d = defaultdict(list)
for nr, col in enumerate(label_cols[0:1]):
    print(nr, col, len(df[col]))
    labels = df[col]
    labels = labels.dropna()
    # labels = labels[labels < 4]
    labels_ind = labels.index
    scaler = False
    if scale_labels:
        # scale the labels
        scaler = StandardScaler()
        labels = scaler.fit_transform(labels.values.reshape(-1, 1))
        labels = pd.Series(labels.flatten(), index=labels_ind)
    input_df = input_df2.loc[labels.index]
    
    # if model_n == 'nn':
    #drop NaNs
    input_df = input_df.dropna(axis=0)
    input_ind = input_df.index
    labels = labels.loc[input_ind]

    #not dropping NaNs, since model can work like that
    print('lens', len(labels), len(input_df))
    print('cols', len(input_df.columns))
    if len(input_df) < 100:
        continue
    
    amount_cols.append(len(input_df.columns))
    assert(labels.index.equals(input_df.index))
    amount_inputs.append(len(input_df))
    scaler_l.append(scaler)

    scaler2 = StandardScaler()    
    if scale_all_data:
        drop_cols = ['Meta; adm0_gaul', 'Meta; GEID_init']
        if leave_out_encodings:
            cols = [c for c in input_df.columns if not any([True for drop_c in ['Meta one-hot encoding;', 'Meta frequency encoding;']
                                                            + drop_cols if drop_c in c])]
            input_df[cols] = scaler2.fit_transform(input_df[cols])
        else:
            cols = [c for c in input_df.columns if c not in drop_cols]
            input_df[cols] = scaler2.fit_transform(input_df[cols])
    else:
        if scale_numerical_data:
            input_df[num_cols] = scaler2.fit_transform(input_df[num_cols])
        
        if zero_one_scale_categorical:
            scaler3 = MinMaxScaler()
            cols = [c for c in input_df.columns if 'DHS Cat;' in c]
            input_df[cols] = scaler3.fit_transform(input_df[cols])
    
    # input_df.to_csv(f"{input_dir}Prefiltered_normalized_grouped_df_V3_{dataset_type}_{group_by_col}_{urban_rural_all_mode}_m_{col}.csv")
       
    fold_gen = fold_generator_3_indices(input_df, fold_by, n_splits=5)
    # Iterate over each fold
    for fold, (train_index, val_index, test_index) in enumerate(fold_gen):
        assert(labels.index.equals(input_df.index))

        X_train, X_val, X_test = input_df.loc[train_index], input_df.loc[val_index], input_df.loc[test_index]
        y_train, y_val, y_test = labels.loc[train_index], labels.loc[val_index], labels.loc[test_index]          
        y_test_index = y_test.index
        
        print(X_train[print_col].unique())
        print(X_test[print_col].unique())
        # print(X_train)
        # print(y_train)
        # drop cols
        drop_cols = ['Meta; adm0_gaul', 'Meta; GEID_init']
        if 'Meta; rounded year' in X_train.columns:
            drop_cols.append('Meta; rounded year')
        X_train = X_train.drop(columns=drop_cols)
        X_val = X_val.drop(columns=drop_cols)
        X_test = X_test.drop(columns=drop_cols)
        
        n_components = False
        if use_pca:
            # create PCA
            n_components = 0.99
            pca = PCA(n_components=n_components)
            pca = pca.fit(X_train)
            X_test = pca.transform(X_test)
            X_train = pca.transform(X_train)
            # Calculate the cumulative explained variance
            cumulative_explained_variance = np.cumsum(pca.explained_variance_ratio_)
            print('PCA', X_train.shape, X_test.shape)
            print('Cumulative explained variance', cumulative_explained_variance)
            print(len(cumulative_explained_variance))
            
        history = False
        if model_n == 'xgb':
            # Initialize the XGBoost model
            model = xgb.XGBRegressor(objective='reg:squarederror', random_state=42)
            # Train the model
            model.fit(X_train, y_train)
        elif model_n == 'nn':
            if use_3_layer_nn:
                # Define the model
                model = Sequential()
                model.add(Dense(256, activation='relu', input_shape=(X_train.shape[1],), kernel_regularizer=regularizer))
                model.add(Dense(64, activation='relu', kernel_regularizer=regularizer))
                # model.add(Dense(32, activation='relu', kernel_regularizer=regularizer))
                if add_dropout:
                    model.add(Dropout(add_dropout))
                model.add(Dense(1, activation='linear'))
            else:
                # Define the model
                model = Sequential()
                model.add(Dense(256, activation='relu', input_shape=(X_train.shape[1],), kernel_regularizer=regularizer))
                if add_dropout:
                    model.add(Dropout(add_dropout))
                model.add(Dense(1, activation='linear'))
                
            # Compile the model
            model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error', metrics=[root_mean_squared_error])

            model_n = 'best_model.keras'
            # Define the ModelCheckpoint callback
            checkpoint = ModelCheckpoint(model_n, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
            
            # Train the model
            history = model.fit(X_train, y_train, epochs=epochs, batch_size=32, validation_data=(X_val, y_val), callbacks=[checkpoint])
            history_l.append(history)
            
            # Evaluate the model on the test set
            test_loss, test_rmse = model.evaluate(X_test, y_test)
            print(f'Test Loss: {test_loss}')
            print(f'Test RMSE: {test_rmse}')
            
            if load_best_model:
                # Load the best model
                model.load_weights(model_n)
            
        # Predict on the test set
        y_pred = model.predict(X_test)
        
        y_test = np.array(y_test)
        if y_test.ndim == 1:
            y_test = y_test.reshape(-1, 1)
        if y_pred.ndim == 1:
            y_pred = y_pred.reshape(-1, 1)
        
        # Inverse transform the predictions
        if scale_labels:
            y_pred = scaler.inverse_transform(y_pred)
            y_test = scaler.inverse_transform(y_test)
        
        if history:
            create_history_figures(history, f"{out_dir}",
                                   fold)
        
        assert len(y_test) == len(y_pred)
        assert len(y_test) == len(y_test_index)        
        # Create a DataFrame with 'Actual' and 'Prediction' columns
        results_df = pd.DataFrame({
            'Actual': y_test.flatten(),
            'Prediction': y_pred.flatten()
        }, index=y_test_index)
        all_results_dfs.append(results_df)
        
        if write_PDP_plots:
            
            # Create partial dependence plots
            create_PDP_plots(X_test, model, f"{input_dir}DHS_PDP_NN/", fold)
        
        if test_mode:
            break
        
all_result_df = pd.concat(all_results_dfs)
print(all_result_df.shape)
print(labels.shape)

missing_mask = missing_mask.loc[all_result_df.index]
final_p_res_df = metrices_weighted_available_data(all_result_df, missing_mask, drop_perc=drop_perc)

# Add options to every row of final_p_res_df
final_p_res_df = final_p_res_df.assign(**options)
print('new', final_p_res_df)
print('old', final_result_df)
create_scatterplot(all_result_df, f"{out_dir}Scatterplot_{col}.png")

# Add results_d to result_df
final_result_df = pd.concat([final_p_res_df, final_result_df])
   
final_result_df.to_csv(result_csv_f, index=False)
final_p_res_df.head(50)
# Out:
# 0 FS; IPC: 0-2y: mean 15252
# lens 5897 5897
# cols 179
# ['NGGE52FL' 'ETGE81FL' 'MDGE71FL' 'NGGE7BFL' 'UGGE5AFL' 'NGGE6AFL'
#  'KEGE71FL' 'UGGE7AFL' 'NIGE61FL' 'MLGE81FL' 'UGGE71FL' 'BFGE61FL'
#  'UGGE61FL' 'MZGE52FL' 'TZGE52FL' 'MLGE63FL' 'CMGE71FL' 'ZMGE61FL'
#  'BFGE71FL' 'KEGE52FL' 'MWGE71FL' 'TDGE71FL' 'MLGE6BFL' 'KEGE7AFL'
#  'NGGE61FL' 'UGGE6AFL' 'ETGE61FL' 'RWGE61FL' 'KEGE81FL' 'MWGE7IFL'
#  'BFGE81FL' 'ETGE71FL' 'MWGE7AFL' 'LBGE71FL' 'MWGE6AFL' 'ZWGE72FL'
#  'MLGE71FL' 'NIGE81FL' 'SLGE71FL' 'ZMGE52FL']
# ['MDGE81FL' 'MLGE7AFL' 'MWGE62FL' 'MZGE61FL' 'MZGE7AFL' 'NGGE71FL'
#  'NGGE81FL' 'TZGE61FL' 'UGGE7IFL' 'ZWGE61FL']
# Epoch 1/30
# 2024-05-13 21:49:26.668618: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-13 21:49:26.668873: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-13 21:49:26.669079: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-13 21:49:26.672265: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-13 21:49:26.672465: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-13 21:49:26.672646: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-13 21:49:26.672822: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-13 21:49:26.673009: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-13 21:49:26.673184: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-13 21:49:26.673977: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-13 21:49:26.871621: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-13 21:49:26.871829: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-13 21:49:26.872006: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-13 21:49:26.872178: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-13 21:49:26.872333: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-13 21:49:26.872486: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-13 21:49:26.872639: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-13 21:49:26.872793: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-13 21:49:26.872945: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-13 21:49:27.522164: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-13 21:49:27.522385: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-13 21:49:27.522561: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-13 21:49:27.522720: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-13 21:49:27.522879: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-13 21:49:27.523031: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-13 21:49:27.523192: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-13 21:49:27.523345: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46706 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:81:00.0, compute capability: 8.6
# 2024-05-13 21:49:27.523717: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-13 21:49:27.523849: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 46634 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:c1:00.0, compute capability: 8.6
# 2024-05-13 21:49:27.524106: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-13 21:49:27.524236: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 46706 MB memory:  -> device: 2, name: NVIDIA RTX A6000, pci bus id: 0000:c2:00.0, compute capability: 8.6
#  94/112 [========================>.....] - ETA: 0s - loss: 11.2192 - root_mean_squared_error: 0.8686
# 2024-05-13 21:49:28.643401: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# Epoch 1: val_loss improved from inf to 5.83445, saving model to best_model.keras
# 112/112 [==============================] - 1s 4ms/step - loss: 10.4962 - root_mean_squared_error: 0.8596 - val_loss: 5.8345 - val_root_mean_squared_error: 0.6766
# Epoch 2/30
# 101/112 [==========================>...] - ETA: 0s - loss: 3.9966 - root_mean_squared_error: 0.6898
# Epoch 2: val_loss improved from 5.83445 to 2.35000, saving model to best_model.keras
# 112/112 [==============================] - 0s 2ms/step - loss: 3.8709 - root_mean_squared_error: 0.6925 - val_loss: 2.3500 - val_root_mean_squared_error: 0.6361
# Epoch 3/30
# 100/112 [=========================>....] - ETA: 0s - loss: 1.7796 - root_mean_squared_error: 0.6627
# Epoch 3: val_loss improved from 2.35000 to 1.19490, saving model to best_model.keras
# 112/112 [==============================] - 0s 2ms/step - loss: 1.7338 - root_mean_squared_error: 0.6653 - val_loss: 1.1949 - val_root_mean_squared_error: 0.6226
# Epoch 4/30
#  95/112 [========================>.....] - ETA: 0s - loss: 1.0223 - root_mean_squared_error: 0.6366
# Epoch 4: val_loss improved from 1.19490 to 0.81764, saving model to best_model.keras
# 112/112 [==============================] - 0s 2ms/step - loss: 0.9964 - root_mean_squared_error: 0.6370 - val_loss: 0.8176 - val_root_mean_squared_error: 0.6306
# Epoch 5/30
# 107/112 [===========================>..] - ETA: 0s - loss: 0.7691 - root_mean_squared_error: 0.6489
# Epoch 5: val_loss improved from 0.81764 to 0.64326, saving model to best_model.keras
# 112/112 [==============================] - 0s 2ms/step - loss: 0.7644 - root_mean_squared_error: 0.6459 - val_loss: 0.6433 - val_root_mean_squared_error: 0.6072
# Epoch 6/30
# 110/112 [============================>.] - ETA: 0s - loss: 0.6414 - root_mean_squared_error: 0.6358
# Epoch 6: val_loss improved from 0.64326 to 0.60804, saving model to best_model.keras
# 112/112 [==============================] - 0s 2ms/step - loss: 0.6396 - root_mean_squared_error: 0.6330 - val_loss: 0.6080 - val_root_mean_squared_error: 0.6372
# Epoch 7/30
# 103/112 [==========================>...] - ETA: 0s - loss: 0.5867 - root_mean_squared_error: 0.6272
# Epoch 7: val_loss improved from 0.60804 to 0.56975, saving model to best_model.keras
# 112/112 [==============================] - 0s 2ms/step - loss: 0.5921 - root_mean_squared_error: 0.6311 - val_loss: 0.5698 - val_root_mean_squared_error: 0.6329
# Epoch 8/30
# 102/112 [==========================>...] - ETA: 0s - loss: 0.5471 - root_mean_squared_error: 0.6212
# Epoch 8: val_loss improved from 0.56975 to 0.54093, saving model to best_model.keras
# 112/112 [==============================] - 0s 2ms/step - loss: 0.5475 - root_mean_squared_error: 0.6190 - val_loss: 0.5409 - val_root_mean_squared_error: 0.6186
# Epoch 9/30
#  97/112 [========================>.....] - ETA: 0s - loss: 0.5440 - root_mean_squared_error: 0.6263
# Epoch 9: val_loss did not improve from 0.54093
# 112/112 [==============================] - 0s 2ms/step - loss: 0.5392 - root_mean_squared_error: 0.6254 - val_loss: 0.5416 - val_root_mean_squared_error: 0.6227
# Epoch 10/30
# 100/112 [=========================>....] - ETA: 0s - loss: 0.5345 - root_mean_squared_error: 0.6187
# Epoch 10: val_loss improved from 0.54093 to 0.50772, saving model to best_model.keras
# 112/112 [==============================] - 0s 2ms/step - loss: 0.5300 - root_mean_squared_error: 0.6161 - val_loss: 0.5077 - val_root_mean_squared_error: 0.6057
# Epoch 11/30
# 103/112 [==========================>...] - ETA: 0s - loss: 0.5103 - root_mean_squared_error: 0.6130
# Epoch 11: val_loss improved from 0.50772 to 0.48375, saving model to best_model.keras
# 112/112 [==============================] - 0s 2ms/step - loss: 0.5049 - root_mean_squared_error: 0.6094 - val_loss: 0.4838 - val_root_mean_squared_error: 0.5920
# Epoch 12/30
#  99/112 [=========================>....] - ETA: 0s - loss: 0.4808 - root_mean_squared_error: 0.5920
# Epoch 12: val_loss did not improve from 0.48375
# 112/112 [==============================] - 0s 2ms/step - loss: 0.4852 - root_mean_squared_error: 0.5982 - val_loss: 0.5284 - val_root_mean_squared_error: 0.6277
# Epoch 13/30
# 103/112 [==========================>...] - ETA: 0s - loss: 0.4839 - root_mean_squared_error: 0.5926
# Epoch 13: val_loss improved from 0.48375 to 0.47935, saving model to best_model.keras
# 112/112 [==============================] - 0s 2ms/step - loss: 0.4841 - root_mean_squared_error: 0.5946 - val_loss: 0.4793 - val_root_mean_squared_error: 0.5934
# Epoch 14/30
#  99/112 [=========================>....] - ETA: 0s - loss: 0.4616 - root_mean_squared_error: 0.5802
# Epoch 14: val_loss did not improve from 0.47935
# 112/112 [==============================] - 0s 2ms/step - loss: 0.4695 - root_mean_squared_error: 0.5872 - val_loss: 0.5018 - val_root_mean_squared_error: 0.6149
# Epoch 15/30
# 104/112 [==========================>...] - ETA: 0s - loss: 0.4710 - root_mean_squared_error: 0.5872
# Epoch 15: val_loss did not improve from 0.47935
# 112/112 [==============================] - 0s 2ms/step - loss: 0.4728 - root_mean_squared_error: 0.5859 - val_loss: 0.4804 - val_root_mean_squared_error: 0.5966
# Epoch 16/30
# 107/112 [===========================>..] - ETA: 0s - loss: 0.4689 - root_mean_squared_error: 0.5897
# Epoch 16: val_loss improved from 0.47935 to 0.46051, saving model to best_model.keras
# 112/112 [==============================] - 0s 2ms/step - loss: 0.4664 - root_mean_squared_error: 0.5848 - val_loss: 0.4605 - val_root_mean_squared_error: 0.5795
# Epoch 17/30
#  97/112 [========================>.....] - ETA: 0s - loss: 0.4514 - root_mean_squared_error: 0.5737
# Epoch 17: val_loss did not improve from 0.46051
# 112/112 [==============================] - 0s 2ms/step - loss: 0.4590 - root_mean_squared_error: 0.5818 - val_loss: 0.4808 - val_root_mean_squared_error: 0.5971
# Epoch 18/30
# 102/112 [==========================>...] - ETA: 0s - loss: 0.4733 - root_mean_squared_error: 0.5909
# Epoch 18: val_loss did not improve from 0.46051
# 112/112 [==============================] - 0s 2ms/step - loss: 0.4687 - root_mean_squared_error: 0.5838 - val_loss: 0.4786 - val_root_mean_squared_error: 0.5930
# Epoch 19/30
# 106/112 [===========================>..] - ETA: 0s - loss: 0.4426 - root_mean_squared_error: 0.5663
# Epoch 19: val_loss did not improve from 0.46051
# 112/112 [==============================] - 0s 2ms/step - loss: 0.4438 - root_mean_squared_error: 0.5678 - val_loss: 0.4765 - val_root_mean_squared_error: 0.5929
# Epoch 20/30
#  99/112 [=========================>....] - ETA: 0s - loss: 0.4518 - root_mean_squared_error: 0.5734
# Epoch 20: val_loss did not improve from 0.46051
# 112/112 [==============================] - 0s 2ms/step - loss: 0.4513 - root_mean_squared_error: 0.5738 - val_loss: 0.4796 - val_root_mean_squared_error: 0.5917
# Epoch 21/30
# 103/112 [==========================>...] - ETA: 0s - loss: 0.4321 - root_mean_squared_error: 0.5524
# Epoch 21: val_loss did not improve from 0.46051
# 112/112 [==============================] - 0s 2ms/step - loss: 0.4328 - root_mean_squared_error: 0.5530 - val_loss: 0.4970 - val_root_mean_squared_error: 0.6072
# Epoch 22/30
#  97/112 [========================>.....] - ETA: 0s - loss: 0.4439 - root_mean_squared_error: 0.5648
# Epoch 22: val_loss did not improve from 0.46051
# 112/112 [==============================] - 0s 2ms/step - loss: 0.4459 - root_mean_squared_error: 0.5709 - val_loss: 0.4739 - val_root_mean_squared_error: 0.5919
# Epoch 23/30
#  98/112 [=========================>....] - ETA: 0s - loss: 0.4406 - root_mean_squared_error: 0.5622
# Epoch 23: val_loss did not improve from 0.46051
# 112/112 [==============================] - 0s 2ms/step - loss: 0.4422 - root_mean_squared_error: 0.5625 - val_loss: 0.4727 - val_root_mean_squared_error: 0.5886
# Epoch 24/30
#  93/112 [=======================>......] - ETA: 0s - loss: 0.4383 - root_mean_squared_error: 0.5572
# Epoch 24: val_loss did not improve from 0.46051
# 112/112 [==============================] - 0s 2ms/step - loss: 0.4370 - root_mean_squared_error: 0.5558 - val_loss: 0.4746 - val_root_mean_squared_error: 0.5900
# Epoch 25/30
#  96/112 [========================>.....] - ETA: 0s - loss: 0.4267 - root_mean_squared_error: 0.5475
# Epoch 25: val_loss did not improve from 0.46051
# 112/112 [==============================] - 0s 2ms/step - loss: 0.4304 - root_mean_squared_error: 0.5532 - val_loss: 0.4622 - val_root_mean_squared_error: 0.5815
# Epoch 26/30
#  94/112 [========================>.....] - ETA: 0s - loss: 0.4255 - root_mean_squared_error: 0.5490
# Epoch 26: val_loss did not improve from 0.46051
# 112/112 [==============================] - 0s 2ms/step - loss: 0.4328 - root_mean_squared_error: 0.5569 - val_loss: 0.4840 - val_root_mean_squared_error: 0.6019
# Epoch 27/30
#  92/112 [=======================>......] - ETA: 0s - loss: 0.4154 - root_mean_squared_error: 0.5421
# Epoch 27: val_loss did not improve from 0.46051
# 112/112 [==============================] - 0s 2ms/step - loss: 0.4157 - root_mean_squared_error: 0.5398 - val_loss: 0.4606 - val_root_mean_squared_error: 0.5785
# Epoch 28/30
#  93/112 [=======================>......] - ETA: 0s - loss: 0.4074 - root_mean_squared_error: 0.5347
# Epoch 28: val_loss did not improve from 0.46051
# 112/112 [==============================] - 0s 2ms/step - loss: 0.4024 - root_mean_squared_error: 0.5300 - val_loss: 0.4625 - val_root_mean_squared_error: 0.5832
# Epoch 29/30
# 102/112 [==========================>...] - ETA: 0s - loss: 0.4031 - root_mean_squared_error: 0.5332
# Epoch 29: val_loss improved from 0.46051 to 0.45529, saving model to best_model.keras
# 112/112 [==============================] - 0s 2ms/step - loss: 0.4027 - root_mean_squared_error: 0.5314 - val_loss: 0.4553 - val_root_mean_squared_error: 0.5782
# Epoch 30/30
# 104/112 [==========================>...] - ETA: 0s - loss: 0.4036 - root_mean_squared_error: 0.5314
# Epoch 30: val_loss improved from 0.45529 to 0.45445, saving model to best_model.keras
# 112/112 [==============================] - 0s 2ms/step - loss: 0.4085 - root_mean_squared_error: 0.5350 - val_loss: 0.4544 - val_root_mean_squared_error: 0.5798
# 46/46 [==============================] - 0s 816us/step - loss: 1.5383 - root_mean_squared_error: 1.1016
# Test Loss: 1.5382988452911377
# Test RMSE: 1.1016212701797485
# dict_keys(['loss', 'root_mean_squared_error', 'val_loss', 'val_root_mean_squared_error'])
# [10.496169090270996, 3.8708789348602295, 1.7337923049926758, 0.996432363986969, 0.7644473314285278, 0.639589786529541, 0.59208744764328, 0.5475255250930786, 0.5392497777938843, 0.5300039649009705, 0.5049103498458862, 0.48524191975593567, 0.484063982963562, 0.46952560544013977, 0.4728054404258728, 0.46636658906936646, 0.4590326249599457, 0.4686608612537384, 0.4438211917877197, 0.45130571722984314, 0.4328254759311676, 0.44593724608421326, 0.4422450065612793, 0.43701526522636414, 0.4303501844406128, 0.4327950179576874, 0.4156931936740875, 0.40243762731552124, 0.40265336632728577, 0.4084966778755188]
# (1448, 2)
# (5897,)
# new      index      RMSE     nRMSE         R2  Correlation  scale_numerical_data  \
# 0       90  0.471714  3.694964 -12.652761     0.085591                 False
# 1       80  0.513958  1.391505  -0.936285     0.223431                 False
# 2       70  0.510340  1.418036  -1.010826     0.224917                 False
# 3       60  0.543349  1.038339  -0.078147     0.232620                 False
# 4  Overall  0.540908  1.037396  -0.076190     0.233338                 False
#
#    scale_all_data  leave_out_encodings  zero_one_scale_categorical  \
# 0            True                False                       False
# 1            True                False                       False
# 2            True                False                       False
# 3            True                False                       False
# 4            True                False                       False
#
#    scale_labels  ...  regularizer_value           add_n  use_imputations  \
# 0          True  ...               0.05  imputed_L2_0.5             True
# 1          True  ...               0.05  imputed_L2_0.5             True
# 2          True  ...               0.05  imputed_L2_0.5             True
# 3          True  ...               0.05  imputed_L2_0.5             True
# 4          True  ...               0.05  imputed_L2_0.5             True
#
#    model_n  fold_by        print_col drop_perc  epochs use_sustainbench  \
# 0       nn   survey  Meta; GEID_init        20      30            False
# 1       nn   survey  Meta; GEID_init        20      30            False
# 2       nn   survey  Meta; GEID_init        20      30            False
# 3       nn   survey  Meta; GEID_init        20      30            False
# 4       nn   survey  Meta; GEID_init        20      30            False
#
#    test_mode
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#
# [5 rows x 27 columns]
# old      level_0    index      RMSE     nRMSE        R2  Correlation  \
# 0          0       90  0.129727  1.016158 -0.032578     0.167164
# 1          1       80  0.204644  0.554058  0.693020     0.839188
# 2          2       70  0.200481  0.557058  0.689686     0.838071
# 3          3       60  0.295828  0.565326  0.680406     0.832203
# 4          4  Overall  0.294939  0.565657  0.680032     0.831968
# ..       ...      ...       ...       ...       ...          ...
# 176        3       60  0.435586  0.936058  0.123795     0.398520
# 177        4       50  0.424414  0.935950  0.123998     0.397518
# 178        5       40  0.424242  0.935895  0.124100     0.397590
# 179        6       30  0.424242  0.935895  0.124100     0.397590
# 180        7       20  0.424242  0.935895  0.124100     0.397590
#
#      scale_numerical_data  scale_all_data  leave_out_encodings  \
# 0                   False            True                False
# 1                   False            True                False
# 2                   False            True                False
# 3                   False            True                False
# 4                   False            True                False
# ..                    ...             ...                  ...
# 176                 False            True                False
# 177                 False            True                False
# 178                 False            True                False
# 179                 False            True                False
# 180                 False            True                False
#
#      zero_one_scale_categorical  ...  regularizer_value           add_n  \
# 0                         False  ...               0.05  imputed_L2_0.5
# 1                         False  ...               0.05  imputed_L2_0.5
# 2                         False  ...               0.05  imputed_L2_0.5
# 3                         False  ...               0.05  imputed_L2_0.5
# 4                         False  ...               0.05  imputed_L2_0.5
# ..                          ...  ...                ...             ...
# 176                       False  ...               0.05  imputed_L2_0.5
# 177                       False  ...               0.05  imputed_L2_0.5
# 178                       False  ...               0.05  imputed_L2_0.5
# 179                       False  ...               0.05  imputed_L2_0.5
# 180                       False  ...               0.05  imputed_L2_0.5
#
#      use_imputations  model_n  fold_by        print_col  drop_perc epochs  \
# 0               True       nn   survey  Meta; GEID_init         20     30
# 1               True       nn   survey  Meta; GEID_init         20     30
# 2               True       nn   survey  Meta; GEID_init         20     30
# 3               True       nn   survey  Meta; GEID_init         20     30
# 4               True       nn   survey  Meta; GEID_init         20     30
# ..               ...      ...      ...              ...        ...    ...
# 176             True       nn   survey  Meta; GEID_init         20     60
# 177             True       nn   survey  Meta; GEID_init         20     60
# 178             True       nn   survey  Meta; GEID_init         20     60
# 179             True       nn   survey  Meta; GEID_init         20     60
# 180             True       nn   survey  Meta; GEID_init         20     60
#
#      use_sustainbench test_mode
# 0               False      True
# 1               False      True
# 2               False      True
# 3               False      True
# 4               False      True
# ..                ...       ...
# 176             False       NaN
# 177             False       NaN
# 178             False       NaN
# 179             False       NaN
# 180             False       NaN
#
# [181 rows x 28 columns]
#      index      RMSE     nRMSE         R2  Correlation  scale_numerical_data  \
# 0       90  0.471714  3.694964 -12.652761     0.085591                 False
# 1       80  0.513958  1.391505  -0.936285     0.223431                 False
# 2       70  0.510340  1.418036  -1.010826     0.224917                 False
# 3       60  0.543349  1.038339  -0.078147     0.232620                 False
# 4  Overall  0.540908  1.037396  -0.076190     0.233338                 False
#
#    scale_all_data  leave_out_encodings  zero_one_scale_categorical  \
# 0            True                False                       False
# 1            True                False                       False
# 2            True                False                       False
# 3            True                False                       False
# 4            True                False                       False
#
#    scale_labels  ...  regularizer_value           add_n  use_imputations  \
# 0          True  ...               0.05  imputed_L2_0.5             True
# 1          True  ...               0.05  imputed_L2_0.5             True
# 2          True  ...               0.05  imputed_L2_0.5             True
# 3          True  ...               0.05  imputed_L2_0.5             True
# 4          True  ...               0.05  imputed_L2_0.5             True
#
#    model_n  fold_by        print_col drop_perc  epochs use_sustainbench  \
# 0       nn   survey  Meta; GEID_init        20      30            False
# 1       nn   survey  Meta; GEID_init        20      30            False
# 2       nn   survey  Meta; GEID_init        20      30            False
# 3       nn   survey  Meta; GEID_init        20      30            False
# 4       nn   survey  Meta; GEID_init        20      30            False
#
#    test_mode
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#
# [5 rows x 27 columns]

# %%
final_p_res_df.head(50)
# Out:
#      index      RMSE     nRMSE         R2  Correlation  scale_numerical_data  \
# 0       90  0.471714  3.694964 -12.652761     0.085591                 False
# 1       80  0.513958  1.391505  -0.936285     0.223431                 False
# 2       70  0.510340  1.418036  -1.010826     0.224917                 False
# 3       60  0.543349  1.038339  -0.078147     0.232620                 False
# 4  Overall  0.540908  1.037396  -0.076190     0.233338                 False
#
#    scale_all_data  leave_out_encodings  zero_one_scale_categorical  \
# 0            True                False                       False
# 1            True                False                       False
# 2            True                False                       False
# 3            True                False                       False
# 4            True                False                       False
#
#    scale_labels  ...  regularizer_value           add_n  use_imputations  \
# 0          True  ...               0.05  imputed_L2_0.5             True
# 1          True  ...               0.05  imputed_L2_0.5             True
# 2          True  ...               0.05  imputed_L2_0.5             True
# 3          True  ...               0.05  imputed_L2_0.5             True
# 4          True  ...               0.05  imputed_L2_0.5             True
#
#    model_n  fold_by        print_col drop_perc  epochs use_sustainbench  \
# 0       nn   survey  Meta; GEID_init        20      30            False
# 1       nn   survey  Meta; GEID_init        20      30            False
# 2       nn   survey  Meta; GEID_init        20      30            False
# 3       nn   survey  Meta; GEID_init        20      30            False
# 4       nn   survey  Meta; GEID_init        20      30            False
#
#    test_mode
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#
# [5 rows x 27 columns]
